# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# 2023-11-03 23:33:19.786127: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-03 23:33:20.838251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 8254494059155884214
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 1
#   links {
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 17334314004779733994
# physical_device_desc: "device: 0, name: Tesla P4, pci bus id: 0000:08:00.0, compute capability: 6.1"
# xla_global_id: 416903419
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 4340353311293075020
# physical_device_desc: "device: 1, name: Tesla P4, pci bus id: 0000:0b:00.0, compute capability: 6.1"
# xla_global_id: 2144165316
# , name: "/device:GPU:2"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 3
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 17325675695239922210
# physical_device_desc: "device: 2, name: Tesla P4, pci bus id: 0000:0e:00.0, compute capability: 6.1"
# xla_global_id: 1651660799
# , name: "/device:GPU:3"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 1
#   links {
#     link {
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 1
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 2
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 16910172310573288176
# physical_device_desc: "device: 3, name: Tesla P4, pci bus id: 0000:17:00.0, compute capability: 6.1"
# xla_global_id: 878896533
# , name: "/device:GPU:4"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 1142628569424223577
# physical_device_desc: "device: 4, name: Tesla P4, pci bus id: 0000:85:00.0, compute capability: 6.1"
# xla_global_id: 615190153
# , name: "/device:GPU:5"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 11031833258995967459
# physical_device_desc: "device: 5, name: Tesla P4, pci bus id: 0000:88:00.0, compute capability: 6.1"
# xla_global_id: 1769886423
# , name: "/device:GPU:6"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 7
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 2594658118126114973
# physical_device_desc: "device: 6, name: Tesla P4, pci bus id: 0000:8b:00.0, compute capability: 6.1"
# xla_global_id: 893286608
# , name: "/device:GPU:7"
# device_type: "GPU"
# memory_limit: 7167672320
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#     link {
#       device_id: 4
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 5
#       type: "StreamExecutor"
#       strength: 1
#     }
#     link {
#       device_id: 6
#       type: "StreamExecutor"
#       strength: 1
#     }
#   }
# }
# incarnation: 6036017253407087802
# physical_device_desc: "device: 7, name: Tesla P4, pci bus id: 0000:94:00.0, compute capability: 6.1"
# xla_global_id: 2099794689
# ]
# 2023-11-03 23:33:31.174229: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:0 with 6835 MB memory:  -> device: 0, name: Tesla P4, pci bus id: 0000:08:00.0, compute capability: 6.1
# 2023-11-03 23:33:31.177050: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:1 with 6835 MB memory:  -> device: 1, name: Tesla P4, pci bus id: 0000:0b:00.0, compute capability: 6.1
# 2023-11-03 23:33:31.178765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:2 with 6835 MB memory:  -> device: 2, name: Tesla P4, pci bus id: 0000:0e:00.0, compute capability: 6.1
# 2023-11-03 23:33:31.180487: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:3 with 6835 MB memory:  -> device: 3, name: Tesla P4, pci bus id: 0000:17:00.0, compute capability: 6.1
# 2023-11-03 23:33:31.182187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:4 with 6835 MB memory:  -> device: 4, name: Tesla P4, pci bus id: 0000:85:00.0, compute capability: 6.1
# 2023-11-03 23:33:31.183901: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:5 with 6835 MB memory:  -> device: 5, name: Tesla P4, pci bus id: 0000:88:00.0, compute capability: 6.1
# 2023-11-03 23:33:31.185596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:6 with 6835 MB memory:  -> device: 6, name: Tesla P4, pci bus id: 0000:8b:00.0, compute capability: 6.1
# 2023-11-03 23:33:31.187328: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /device:GPU:7 with 6835 MB memory:  -> device: 7, name: Tesla P4, pci bus id: 0000:94:00.0, compute capability: 6.1

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
tf.sysconfig.get_build_info()
# Out:
# OrderedDict([('cpu_compiler', '/dt9/usr/bin/gcc'),
#              ('cuda_compute_capabilities',
#               ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']),
#              ('cuda_version', '11.8'),
#              ('cudnn_version', '8'),
#              ('is_cuda_build', True),
#              ('is_rocm_build', False),
#              ('is_tensorrt_build', True)])

# %%
print(tf.config.list_physical_devices(device_type='GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:5', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:6', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:7', device_type='GPU')]
